# %%
import tensorflow as tf
import cv2
import os
import matplotlib.pyplot as plt
import numpy as np

# %%
img = cv2.imread("training/0/Training_3908.jpg")

# %%
if img is not None:
    print(img.shape)
else:
    print("Failed to load the image.")
# Out:
# (48, 48, 3)

# %%
print(img)
# Out:
# [[[163 163 163]
#   [128 128 128]
#   [114 114 114]
#   ...
#   [139 139 139]
#   [141 141 141]
#   [134 134 134]]
#
#  [[147 147 147]
#   [114 114 114]
#   [102 102 102]
#   ...
#   [142 142 142]
#   [138 138 138]
#   [138 138 138]]
#
#  [[112 112 112]
#   [106 106 106]
#   [ 92  92  92]
#   ...
#   [140 140 140]
#   [141 141 141]
#   [134 134 134]]
#
#  ...
#
#  [[139 139 139]
#   [141 141 141]
#   [136 136 136]
#   ...
#   [154 154 154]
#   [171 171 171]
#   [191 191 191]]
#
#  [[140 140 140]
#   [133 133 133]
#   [120 120 120]
#   ...
#   [138 138 138]
#   [146 146 146]
#   [158 158 158]]
#
#  [[136 136 136]
#   [134 134 134]
#   [113 113 113]
#   ...
#   [146 146 146]
#   [144 144 144]
#   [144 144 144]]]

# %%
plt.imshow(img)

# %%
Datadictionary = "training/"

# %%
classes=["0","1","2","3","4","5","6"]

# %%
for category in classes:
    path=os.path.join(Datadictionary,category)
    for img in os.listdir(path):
        img_array=cv2.imread(os.path.join(path,img))
        plt.imshow(cv2.cvtColor(img_array,cv2.COLOR_BGR2RGB))
        plt.show()
        break
    break

# %%
img_size=150
new_array = cv2.resize(img_array,(img_size,img_size))
plt.imshow(cv2.cvtColor(new_array,cv2.COLOR_BGR2RGB))
plt.show()

# %%
new_array.shape
# Out:
# (150, 150, 3)

# %% [markdown]
# # Read All the images and convert them to Array

# %%
training_Data =[]
def create_training_Data():
    for category in classes:
        path=os.path.join(Datadictionary,category)
        class_num=classes.index(category)
        for img in os.listdir(path):
            try:
                img_array=cv2.imread(os.path.join(path,img))
                new_array=cv2.resize(img_array, (img_size,img_size))
                training_Data.append([new_array,class_num])
            except Exception as e:
                pass

# %%
create_training_Data()

# %%
print(len(training_Data))
# Out:
# 13759

# %%
# temp = np.array(training_Data)

# %%
# temp.shape

# %%
import random 
random.shuffle(training_Data)

# %%
X = []
Y = []
for features,label in training_Data:
    X.append(features)
    Y.append(label)
X = np.array(X).reshape(-1,img_size,img_size,3)# four dimension conversion

# %%
X.shape
# Out:
# (13759, 150, 150, 3)

# %% [markdown]
# # data normalize

# %%
X=X/255.0;

# %%
Y[1000]
# Out:
# 0

# %%
Y[14]
# Out:
# 2

# %%
# Y.shape ## throws an error beaceuse of list

# %%
Y[0]
# Out:
# 0

# %%
type(Y)
# Out:
# list

# %%
y = np.array(Y)

# %%
y.shape
# Out:
# (13759,)

# %% [markdown]
# # Deep Learning Model for training Transfer Learning

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
model = tf.keras.applications.MobileNetV2() ## Pre-trained model

# %%
model.summary()
# Out:
# Model: "mobilenetv2_1.00_224"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ...
#  input_1 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  Conv1 (Conv2D)              (None, 112, 112, 32)         864       ['input_1[0][0]']
#
#  bn_Conv1 (BatchNormalizati  (None, 112, 112, 32)         128       ['Conv1[0][0]']
#  on)
#
#  Conv1_relu (ReLU)           (None, 112, 112, 32)         0         ['bn_Conv1[0][0]']
#
#  expanded_conv_depthwise (D  (None, 112, 112, 32)         288       ['Conv1_relu[0][0]']
#  epthwiseConv2D)
#
#  expanded_conv_depthwise_BN  (None, 112, 112, 32)         128       ['expanded_conv_depthwise[0][0
#   (BatchNormalization)                                              ]']
#
#  expanded_conv_depthwise_re  (None, 112, 112, 32)         0         ['expanded_conv_depthwise_BN[0
# ...

# %% [markdown]
# # Transfer Learning - tuning ,weights will start from last check point

# %%
base_input = model.layers[0].input

# %%
base_output = model.layers[-2].output

# %%
base_output
# Out:
# <KerasTensor: shape=(None, 1280) dtype=float32 (created by layer 'global_average_pooling2d')>

# %%
final_output = layers.Dense(128)(base_output)# adding new layer , after the output 
final_output = layers.Activation('relu')(final_output)
final_output = layers.Dense(64)(final_output)
final_output = layers.Activation('relu')(final_output)
final_output = layers.Dense(7,activation='softmax')(final_output)# because of 7 classes

# %%
final_output
# Out:
# <KerasTensor: shape=(None, 7) dtype=float32 (created by layer 'dense_2')>

# %%
new_model = keras.Model(inputs = base_input , outputs = final_output)

# %%
new_model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ...
#  input_1 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  Conv1 (Conv2D)              (None, 112, 112, 32)         864       ['input_1[0][0]']
#
#  bn_Conv1 (BatchNormalizati  (None, 112, 112, 32)         128       ['Conv1[0][0]']
#  on)
#
#  Conv1_relu (ReLU)           (None, 112, 112, 32)         0         ['bn_Conv1[0][0]']
#
#  expanded_conv_depthwise (D  (None, 112, 112, 32)         288       ['Conv1_relu[0][0]']
#  epthwiseConv2D)
#
#  expanded_conv_depthwise_BN  (None, 112, 112, 32)         128       ['expanded_conv_depthwise[0][0
#   (BatchNormalization)                                              ]']
#
#  expanded_conv_depthwise_re  (None, 112, 112, 32)         0         ['expanded_conv_depthwise_BN[0
# ...

# %%
# new_model.compile(loss="sparse_categorical_crossentropy",optimizer="adam",metrices=["accuracy"])
new_model.compile(loss="sparse_categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# new_model.fit(X,y,epochs=25)
new_model.fit(X, y, batch_size=32, epochs=25)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[50], line 2
#       1 # new_model.fit(X,y,epochs=25)
# ----> 2 new_model.fit(X, y, batch_size=32, epochs=25)
#
# File D:\anaconda\Lib\site-packages\keras\src\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File D:\anaconda\Lib\site-packages\tensorflow\python\framework\constant_op.py:90, in convert_to_eager_tensor(value, ctx, dtype)
#      70 """Converts the given `value` to an `EagerTensor`.
#      71
#      72 Note that this function could return cached copies of created constants for
# ...
